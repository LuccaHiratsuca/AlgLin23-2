# %% [markdown]
# ![image.png](attachment:image.png)

# %%
import numpy as np

X = np.array([0.21, 0.09, 0.06, 0.12, 0.10, 0.02, 0.17, 0.11, 0.13, 0.00])

# Calculate the entropy
H_X = -np.sum(X[X > 0] * np.log2(X[X > 0]))

H_X
# Out:
# 3.0086654587195776
